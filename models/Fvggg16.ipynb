# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk(r'/content/drive/MyDrive/dataset-resized'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /content/drive/MyDrive/dataset-resized/paper/paper105.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper106.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper114.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper1.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper107.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper110.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper10.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper100.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper115.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper113.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper112.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper101.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper11.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper109.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper102.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper104.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper103.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper108.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper116.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper111.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper137.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper121.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper128.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper14.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper125.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper120.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper117.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper144.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper12.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper146.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper123.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper118.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper132.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper142.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper126.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper13.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper124.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper135.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper131.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper130.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper136.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper140.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper143.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper138.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper139.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper119.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper129.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper133.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper145.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper127.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper134.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper122.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper141.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper151.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper167.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper163.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper153.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper161.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper166.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper164.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper154.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper160.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper152.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper155.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper158.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper168.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper149.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper157.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper174.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper156.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper150.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper169.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper15.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper148.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper162.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper172.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper159.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper165.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper173.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper170.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper17.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper16.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper147.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper171.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper189.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper191.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper192.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper183.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper198.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper190.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper200.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper19.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper181.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper178.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper179.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper18.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper180.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper2.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper196.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper193.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper186.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper197.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper177.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper182.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper184.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper176.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper201.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper20.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper175.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper185.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper187.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper194.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper188.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper195.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper199.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper206.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper215.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper222.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper212.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper218.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper220.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper23.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper203.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper207.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper210.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper22.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper224.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper217.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper208.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper216.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper202.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper219.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper229.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper211.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper205.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper214.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper227.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper223.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper230.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper213.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper21.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper221.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper228.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper209.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper204.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper225.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper226.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper252.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper232.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper256.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper231.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper244.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper241.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper247.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper254.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper237.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper253.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper233.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper243.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper255.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper25.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper250.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper240.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper249.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper239.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper238.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper235.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper234.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper236.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper24.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper258.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper257.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper242.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper246.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper245.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper248.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper251.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper287.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper269.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper265.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper271.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper266.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper268.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper275.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper27.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper260.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper263.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper264.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper283.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper285.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper276.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper284.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper278.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper286.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper273.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper272.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper28.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper282.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper274.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper261.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper277.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper270.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper288.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper262.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper26.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper280.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper259.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper281.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper267.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper279.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper30.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper315.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper293.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper29.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper3.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper313.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper309.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper295.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper312.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper303.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper305.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper314.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper299.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper292.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper311.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper302.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper316.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper301.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper304.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper308.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper291.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper307.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper31.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper310.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper300.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper296.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper289.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper298.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper306.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper290.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper294.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper297.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper336.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper332.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper328.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper329.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper324.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper32.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper34.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper317.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper342.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper325.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper340.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper341.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper330.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper320.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper343.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper319.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper333.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper339.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper337.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper338.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper345.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper322.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper33.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper321.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper323.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper344.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper318.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper334.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper326.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper331.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper335.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper327.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper354.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper355.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper356.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper348.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper369.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper368.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper372.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper366.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper353.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper357.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper358.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper373.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper351.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper35.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper365.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper364.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper371.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper362.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper347.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper360.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper350.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper352.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper363.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper361.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper374.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper370.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper349.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper359.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper367.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper346.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper37.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper36.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper393.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper388.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper384.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper389.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper375.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper402.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper381.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper395.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper377.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper4.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper396.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper382.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper383.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper397.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper378.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper40.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper376.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper385.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper404.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper387.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper391.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper394.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper392.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper398.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper380.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper403.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper38.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper399.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper401.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper390.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper400.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper386.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper379.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper39.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper409.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper424.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper407.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper414.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper413.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper428.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper406.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper410.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper423.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper418.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper415.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper408.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper422.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper405.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper426.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper430.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper427.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper416.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper42.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper425.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper431.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper420.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper41.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper43.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper429.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper421.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper412.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper417.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper411.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper419.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper458.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper445.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper443.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper439.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper454.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper449.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper450.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper451.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper434.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper435.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper446.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper459.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper448.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper444.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper447.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper437.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper46.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper433.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper455.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper453.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper452.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper438.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper460.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper442.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper436.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper441.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper456.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper45.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper457.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper44.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper432.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper440.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper464.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper49.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper487.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper483.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper485.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper48.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper471.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper488.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper463.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper486.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper481.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper462.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper476.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper469.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper482.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper470.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper47.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper468.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper474.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper478.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper467.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper465.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper479.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper461.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper466.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper473.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper472.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper484.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper477.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper475.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper480.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper489.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper516.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper51.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper500.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper515.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper495.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper514.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper510.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper505.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper50.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper490.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper512.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper499.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper492.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper507.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper518.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper511.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper491.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper497.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper494.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper506.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper501.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper509.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper5.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper517.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper508.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper493.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper504.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper502.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper496.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper503.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper513.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper498.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper522.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper521.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper543.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper520.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper539.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper542.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper546.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper535.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper523.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper547.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper528.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper531.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper527.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper538.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper53.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper532.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper541.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper537.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper526.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper52.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper533.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper519.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper540.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper544.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper534.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper524.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper536.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper54.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper530.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper525.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper545.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper529.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper569.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper558.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper561.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper560.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper548.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper552.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper574.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper55.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper549.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper553.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper570.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper575.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper550.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper557.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper559.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper563.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper562.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper551.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper566.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper576.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper57.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper571.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper565.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper556.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper572.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper554.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper573.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper568.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper564.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper567.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper555.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper56.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper587.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper577.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper589.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper70.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper67.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper590.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper592.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper69.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper58.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper591.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper588.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper580.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper60.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper64.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper578.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper6.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper583.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper586.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper582.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper65.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper579.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper68.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper62.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper585.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper594.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper593.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper61.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper581.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper63.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper66.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper584.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper59.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper7.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper85.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper80.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper73.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper74.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper95.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper79.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper88.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper99.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper94.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper9.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper91.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper96.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper8.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper78.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper84.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper83.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper81.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper97.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper93.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper75.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper87.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper76.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper72.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper98.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper86.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper77.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper71.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper89.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper82.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper92.jpg
# /content/drive/MyDrive/dataset-resized/paper/paper90.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass104.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass108.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass11.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass116.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass1.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass109.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass107.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass105.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass115.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass113.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass101.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass119.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass100.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass111.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass103.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass114.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass102.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass112.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass118.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass110.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass117.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass10.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass106.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass137.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass142.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass149.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass147.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass125.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass124.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass133.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass139.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass14.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass130.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass143.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass127.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass131.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass128.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass129.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass135.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass145.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass148.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass12.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass136.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass134.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass120.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass140.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass122.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass146.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass126.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass144.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass123.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass132.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass13.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass138.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass121.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass141.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass169.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass165.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass166.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass168.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass157.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass15.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass16.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass175.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass161.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass155.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass153.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass176.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass173.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass167.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass17.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass152.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass156.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass162.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass174.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass172.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass177.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass154.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass158.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass151.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass171.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass178.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass160.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass159.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass170.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass150.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass164.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass163.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass191.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass18.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass181.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass205.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass195.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass196.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass188.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass190.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass183.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass185.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass199.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass197.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass189.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass204.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass182.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass193.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass192.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass2.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass201.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass194.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass203.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass200.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass19.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass20.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass198.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass206.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass184.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass180.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass186.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass202.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass187.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass179.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass23.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass234.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass208.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass209.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass222.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass235.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass211.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass229.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass217.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass225.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass231.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass210.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass227.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass223.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass215.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass214.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass207.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass21.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass224.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass213.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass221.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass218.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass226.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass219.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass233.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass22.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass216.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass232.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass230.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass228.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass212.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass220.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass248.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass259.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass262.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass260.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass255.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass240.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass241.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass237.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass239.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass258.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass252.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass25.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass26.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass249.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass244.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass251.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass250.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass245.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass254.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass256.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass242.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass236.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass265.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass264.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass238.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass263.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass253.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass247.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass243.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass261.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass246.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass257.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass24.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass270.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass271.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass290.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass275.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass276.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass28.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass286.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass282.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass283.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass285.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass266.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass291.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass294.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass29.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass292.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass268.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass293.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass277.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass295.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass267.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass273.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass287.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass280.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass278.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass269.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass279.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass289.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass281.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass288.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass284.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass272.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass274.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass27.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass303.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass310.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass308.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass299.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass30.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass300.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass319.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass3.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass320.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass311.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass307.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass298.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass301.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass316.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass31.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass304.jpg
# /content/drive/MyDrive/dataset-resized/glass/glass296.jpg
# ...
# /content/drive/MyDrive/dataset-resized/metal/metal199.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal202.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal220.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal204.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal206.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal223.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal231.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal250.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal230.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal233.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal245.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal246.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal238.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal232.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal244.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal248.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal224.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal243.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal237.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal236.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal241.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal225.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal242.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal25.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal226.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal228.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal239.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal227.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal24.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal252.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal247.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal249.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal240.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal251.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal23.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal234.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal235.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal229.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal281.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal257.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal259.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal255.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal277.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal260.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal264.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal258.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal265.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal267.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal269.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal254.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal270.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal253.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal266.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal26.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal278.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal256.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal275.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal272.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal273.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal263.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal280.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal262.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal268.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal28.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal279.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal274.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal276.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal261.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal271.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal27.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal31.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal284.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal297.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal289.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal296.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal290.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal307.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal285.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal299.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal310.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal304.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal306.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal29.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal282.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal308.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal294.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal292.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal287.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal300.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal293.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal30.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal3.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal288.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal295.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal303.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal305.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal309.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal291.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal298.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal301.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal283.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal302.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal286.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal33.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal311.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal314.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal336.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal313.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal318.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal34.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal337.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal32.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal324.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal315.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal330.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal339.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal331.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal335.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal326.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal329.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal325.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal317.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal334.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal312.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal323.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal327.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal333.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal332.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal338.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal328.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal319.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal321.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal316.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal320.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal322.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal344.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal354.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal351.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal357.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal368.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal362.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal342.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal359.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal360.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal340.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal363.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal358.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal365.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal37.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal353.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal361.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal343.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal35.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal348.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal349.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal364.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal346.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal366.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal352.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal341.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal367.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal345.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal355.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal356.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal347.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal350.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal36.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal369.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal397.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal370.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal389.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal381.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal385.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal379.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal384.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal393.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal39.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal38.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal398.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal399.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal375.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal386.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal390.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal394.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal395.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal382.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal378.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal383.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal374.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal371.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal391.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal377.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal396.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal387.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal388.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal380.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal373.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal372.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal376.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal392.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal41.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal4.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal42.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal44.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal55.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal53.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal409.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal403.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal45.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal400.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal58.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal47.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal48.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal56.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal57.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal54.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal46.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal51.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal407.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal43.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal50.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal49.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal59.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal405.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal404.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal401.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal5.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal52.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal406.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal408.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal402.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal410.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal40.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal85.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal77.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal83.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal75.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal82.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal79.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal60.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal65.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal86.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal78.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal61.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal76.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal74.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal80.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal72.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal66.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal63.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal7.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal64.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal70.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal81.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal71.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal69.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal88.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal8.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal87.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal6.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal68.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal84.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal73.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal67.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal62.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal90.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal91.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal95.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal93.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal92.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal94.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal97.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal9.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal99.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal96.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal89.jpg
# /content/drive/MyDrive/dataset-resized/metal/metal98.jpg

# %%
import numpy as np
import pandas as pd
import os
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import keras
from tqdm import tqdm
from keras.callbacks import EarlyStopping,ModelCheckpoint
from sklearn.metrics import confusion_matrix , accuracy_score
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings('ignore')

# %%
#Create Files_Name
image_data="/content/drive/MyDrive/dataset-resized"
pd.DataFrame(os.listdir(image_data),columns=['Files_Name'])
# Out:
#   Files_Name
# 0      paper
# 1      glass
# 2      trash
# 3    plastic
# 4  cardboard
# 5      metal

# %%
import tensorflow as tf

# Define parameters
train_data_dir = image_data
batch_size = 32
target_size = (224, 224)
validation_split = 0.1
test_split = 0.2

# Load the entire dataset
full_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    train_data_dir,
    validation_split=validation_split,
    subset="training",
    seed=100,
    image_size=target_size,
    batch_size=batch_size,
)

# Split the dataset into training and validation subsets
num_examples = full_dataset.cardinality().numpy()
train_size = int((1 - validation_split - test_split) * num_examples)
val_size = int(validation_split * num_examples)

train_dataset = full_dataset.take(train_size)
validation_dataset = full_dataset.skip(train_size).take(val_size)

# Load the test dataset
test_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    train_data_dir,
    validation_split=validation_split,
    subset="validation",
    seed=200,
    image_size=target_size,
    batch_size=batch_size,
)
# Out:
# Found 2527 files belonging to 6 classes.
# Using 2275 files for training.
# Found 2527 files belonging to 6 classes.
# Using 252 files for validation.

# %%
class_names = full_dataset.class_names
class_names
# Out:
# ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']

# %%
plt.figure(figsize=(15, 20))
for images, labels in train_dataset.take(1):
    for i in range(8):
        ax = plt.subplot(8, 4, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
import tensorflow as tf
from tensorflow import keras

# Define VGG16 with pre-trained weights
base_model = tf.keras.applications.VGG16(input_shape=(224, 224, 3), include_top=False, weights='imagenet')
base_model.trainable = False

# Build the sequential model
keras_model = keras.models.Sequential([
    base_model,
    keras.layers.Flatten(),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(6, activation=tf.nn.softmax)
])

# Provide a sample input
sample_input = tf.random.normal((1, 224, 224, 3))

# Call the model with the sample input to initialize the shapes
_ = keras_model(sample_input)

# Print model summary
keras_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten_1 (Flatten)         (None, 25088)             0
#
#  dropout_1 (Dropout)         (None, 25088)             0
#
#  dense_1 (Dense)             (None, 6)                 150534
#
# =================================================================
# Total params: 14865222 (56.71 MB)
# Trainable params: 150534 (588.02 KB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %%
checkpoint = ModelCheckpoint(filepath='model.keras', monitor='val_accuracy', save_best_only=True)
early_stopping =EarlyStopping(patience=5, restore_best_weights=True)
keras_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
hist = keras_model.fit(train_dataset, epochs=10, validation_data=validation_dataset, callbacks=[checkpoint, early_stopping])
# Out:
# Epoch 1/10
# 50/50 [==============================] - 48s 281ms/step - loss: 0.9575 - accuracy: 0.9556 - val_loss: 3.7157 - val_accuracy: 0.8929
# Epoch 2/10
# 50/50 [==============================] - 15s 289ms/step - loss: 1.0268 - accuracy: 0.9588 - val_loss: 4.2623 - val_accuracy: 0.9018
# Epoch 3/10
# 50/50 [==============================] - 19s 354ms/step - loss: 1.1547 - accuracy: 0.9506 - val_loss: 4.9135 - val_accuracy: 0.9018
# Epoch 4/10
# 50/50 [==============================] - 15s 284ms/step - loss: 0.8267 - accuracy: 0.9613 - val_loss: 5.5848 - val_accuracy: 0.9018
# Epoch 5/10
# 50/50 [==============================] - 27s 540ms/step - loss: 1.0669 - accuracy: 0.9613 - val_loss: 6.7580 - val_accuracy: 0.8839
# Epoch 6/10
# 50/50 [==============================] - 15s 282ms/step - loss: 1.2492 - accuracy: 0.9575 - val_loss: 2.9168 - val_accuracy: 0.9152
# Epoch 7/10
# 50/50 [==============================] - 19s 356ms/step - loss: 0.8888 - accuracy: 0.9706 - val_loss: 5.8590 - val_accuracy: 0.9018
# Epoch 8/10
# 50/50 [==============================] - 18s 351ms/step - loss: 0.5636 - accuracy: 0.9756 - val_loss: 4.7447 - val_accuracy: 0.9152
# Epoch 9/10
# 50/50 [==============================] - 14s 275ms/step - loss: 1.0109 - accuracy: 0.9712 - val_loss: 5.4489 - val_accuracy: 0.9062
# Epoch 10/10
# 50/50 [==============================] - 19s 353ms/step - loss: 0.8364 - accuracy: 0.9712 - val_loss: 6.8630 - val_accuracy: 0.8884

# %%
# Unfreeze some layers of the base model
base_model.trainable = True

# Fine-tune from this layer onwards
fine_tune_at = 15

# Freeze all layers before the `fine_tune_at` layer
for layer in base_model.layers[:fine_tune_at]:
    layer.trainable = False

# Compile the model
keras_model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-5),
                     loss='sparse_categorical_crossentropy',
                     metrics=['accuracy'])

# Train the model
history = keras_model.fit(train_dataset,
                          epochs=10,
                          validation_data=validation_dataset)
# Out:
# Epoch 1/10
# 50/50 [==============================] - 22s 377ms/step - loss: 0.4355 - accuracy: 0.9825 - val_loss: 4.8353 - val_accuracy: 0.9152
# Epoch 2/10
# 50/50 [==============================] - 20s 377ms/step - loss: 0.4526 - accuracy: 0.9825 - val_loss: 4.6482 - val_accuracy: 0.9196
# Epoch 3/10
# 50/50 [==============================] - 16s 313ms/step - loss: 0.1826 - accuracy: 0.9912 - val_loss: 4.0023 - val_accuracy: 0.9330
# Epoch 4/10
# 50/50 [==============================] - 19s 373ms/step - loss: 0.2116 - accuracy: 0.9875 - val_loss: 5.6005 - val_accuracy: 0.8929
# Epoch 5/10
# 50/50 [==============================] - 17s 326ms/step - loss: 0.1380 - accuracy: 0.9906 - val_loss: 4.1622 - val_accuracy: 0.9196
# Epoch 6/10
# 50/50 [==============================] - 19s 374ms/step - loss: 0.2402 - accuracy: 0.9856 - val_loss: 3.9999 - val_accuracy: 0.9330
# Epoch 7/10
# 50/50 [==============================] - 18s 338ms/step - loss: 0.1857 - accuracy: 0.9881 - val_loss: 2.6067 - val_accuracy: 0.9598
# Epoch 8/10
# 50/50 [==============================] - 17s 320ms/step - loss: 0.1207 - accuracy: 0.9900 - val_loss: 4.4210 - val_accuracy: 0.9330
# Epoch 9/10
# 50/50 [==============================] - 17s 316ms/step - loss: 0.1063 - accuracy: 0.9944 - val_loss: 3.9974 - val_accuracy: 0.9420
# Epoch 10/10
# 50/50 [==============================] - 20s 373ms/step - loss: 0.1173 - accuracy: 0.9925 - val_loss: 4.4741 - val_accuracy: 0.9152

# %%
tf.keras.utils.plot_model(keras_model, to_file='model.png', show_shapes=True, show_layer_names=True,show_dtype=True,dpi=80)

# %%
hist_=pd.DataFrame(history.history)
hist_
# Out:
#        loss  accuracy  val_loss  val_accuracy
# 0  0.435535  0.982500  4.835298      0.915179
# 1  0.452596  0.982500  4.648229      0.919643
# 2  0.182608  0.991250  4.002331      0.933036
# 3  0.211600  0.987500  5.600545      0.892857
# 4  0.138037  0.990625  4.162197      0.919643
# 5  0.240180  0.985625  3.999886      0.933036
# 6  0.185739  0.988125  2.606750      0.959821
# 7  0.120714  0.990000  4.421041      0.933036
# 8  0.106286  0.994375  3.997402      0.941964
# 9  0.117275  0.992500  4.474075      0.915179

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(hist_['loss'],label='Train_Loss')
plt.plot(hist_['val_loss'],label='Validation_Loss')
plt.title('Train_Loss & Validation_Loss',fontsize=20)
plt.legend()
plt.subplot(1,2,2)
plt.plot(hist_['accuracy'],label='Train_Accuracy')
plt.plot(hist_['val_accuracy'],label='Validation_Accuracy')
plt.title('Train_Accuracy & Validation_Accuracy',fontsize=20)
plt.legend()

# %%
X_val,y_val,y_pred=[],[],[]
for images, labels in validation_dataset:
    y_val.extend(labels.numpy())
    X_val.extend(images.numpy())
predictions=keras_model.predict(np.array(X_val))
for i in predictions:
    y_pred.append(np.argmax(i))
df=pd.DataFrame()
df['Actual'],df['Prediction']=y_val,y_pred
df
# Out:
# 7/7 [==============================] - 1s 142ms/step
#      Actual  Prediction
# 0         0           0
# 1         1           1
# 2         2           2
# 3         5           5
# 4         2           2
# ..      ...         ...
# 219       5           5
# 220       2           2
# 221       3           3
# 222       2           2
# 223       2           2
#
# [224 rows x 2 columns]

# %%
plt.figure(figsize=(25,25))
for i in range(32):
    ax = plt.subplot(8, 4, i + 1)
    plt.imshow(X_val[i].astype("uint8"))
    plt.title(f'{class_names[y_val[i]]} :: {class_names[y_pred[i]]}')
    plt.axis("off")

# %%
ax= plt.subplot()
CM = confusion_matrix(y_val,y_pred)
sns.heatmap(CM, annot=True, fmt='g', ax=ax,cbar=False,cmap='RdBu')
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix')
plt.show()
CM
# Out:
# array([[29,  0,  0,  1,  0,  0],
#        [ 0, 36,  0,  0,  3,  0],
#        [ 0,  0, 34,  0,  1,  1],
#        [ 1,  0,  0, 55,  0,  0],
#        [ 1,  2,  0,  2, 43,  1],
#        [ 0,  0,  0,  0,  0, 14]])

# %%
plt.figure(figsize=(25, 25))
plot_count = 1  # Counter to keep track of the number of plotted images
for i in range(len(X_val)):
    if class_names[y_val[i]] != class_names[y_pred[i]]:
        ax = plt.subplot(8, 4, plot_count)
        plt.imshow(X_val[i].astype("uint8"))
        ax.title.set_text(f"Actual: {class_names[y_val[i]]}\nPredicted: {class_names[y_pred[i]]}")
        plot_count += 1
        if plot_count > 32:  # Plot up to 32 mismatched images
            break
plt.show()

# %%
# prompt: give me the accuracy of each class

from sklearn.metrics import classification_report

# Get the classification report
report = classification_report(y_val, y_pred)

# Print the accuracy for each class
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95        30
#            1       0.95      0.92      0.94        39
#            2       1.00      0.94      0.97        36
#            3       0.95      0.98      0.96        56
#            4       0.91      0.88      0.90        49
#            5       0.88      1.00      0.93        14
#
#     accuracy                           0.94       224
#    macro avg       0.94      0.95      0.94       224
# weighted avg       0.94      0.94      0.94       224

# %%
# prompt: print the index and class label of each

# Create a dictionary to store the class names and their corresponding indices
class_names = full_dataset.class_names
class_names_to_indices = {class_name: i for i, class_name in enumerate(class_names)}

# Print the index and class label for each class
for class_name, index in class_names_to_indices.items():
  print(f"Index: {index}, Class Label: {class_name}")
# Out:
# Index: 0, Class Label: cardboard
# Index: 1, Class Label: glass
# Index: 2, Class Label: metal
# Index: 3, Class Label: paper
# Index: 4, Class Label: plastic
# Index: 5, Class Label: trash

# %%
from sklearn.metrics import accuracy_score
import numpy as np

# Convert y_val and y_pred to NumPy arrays if they are not already
y_val = np.array(y_val)
y_pred = np.array(y_pred)

# Calculate the accuracy for each class
class_accuracies = {}
unique_labels = np.unique(y_val)
for label in unique_labels:
    indices = np.where(y_val == label)[0]  # Get indices where y_val equals the current label
    class_accuracies[label] = accuracy_score(y_val[indices], y_pred[indices])

# Print the accuracy for each class
for label, accuracy in class_accuracies.items():
    print(f"Accuracy for class {label}: {accuracy:.3f}")
# Out:
# Accuracy for class 0: 0.967
# Accuracy for class 1: 0.923
# Accuracy for class 2: 0.944
# Accuracy for class 3: 0.982
# Accuracy for class 4: 0.878
# Accuracy for class 5: 1.000

# %%
Acc = accuracy_score(y_val,y_pred)
print("accuracy is: {0:.3f}%".format(Acc * 100))
# Out:
# accuracy is: 94.196%

# %%
# prompt: give me the precision of the completer model

from sklearn.metrics import  precision_score

# Calculate precision for each class
precision = precision_score(y_val, y_pred, average='weighted')

# Print the precision
print(f"Precision: {precision:.3f}")
# Out:
# Precision: 0.943

# %%
# prompt: give me the precision of the completer model

from sklearn.metrics import  recall_score

# Calculate precision for each class
recall = recall_score(y_val, y_pred, average='weighted')

# Print the precision
print(f"recall: {recall:.3f}")
# Out:
# recall: 0.942

# %%
from sklearn.metrics import f1_score

# Calculate F1-score for each class
f1 = f1_score(y_val, y_pred, average='weighted')

# Print the F1-score
print(f"F1-score: {f1:.3f}")
# Out:
# F1-score: 0.942

# %%
# prompt: save the model in mydrive

keras_model.save('/content/drive/MyDrive/models/vgg16model.keras')

# %%
recycle=class_names[0:5]

# %%
img = cv2.imread(r'/content/drive/MyDrive/dataset-resized/trash/trash45.jpg')
resized_image = cv2.resize(img, (224, 224))
resized_image.shape
import numpy as np
resized_image = np.expand_dims(resized_image, axis=0)
predicted=keras_model.predict(resized_image)
predicted_class=np.argmax(predicted)
class_label=class_names[predicted_class]
print(class_label,end="-")
if class_label in recycle:
    print("recyclable object")
else:
    print("Non Recyclable object")
# Out:
# 1/1 [==============================] - 0s 36ms/step
# trash-Non Recyclable object

# %%
# prompt: load the saved model

loaded_model = tf.keras.models.load_model('/content/drive/MyDrive/models/vgg16model.keras')

# %%
import keras
print(keras.version())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-5a3e222426a9> in <cell line: 2>()
#       1 import keras
# ----> 2 print(keras.version())
#
# AttributeError: module 'keras' has no attribute 'version'

# %%
# prompt: keras version
import tensorflow
print(tensorflow.__version__)
# Out:
# 2.15.0
